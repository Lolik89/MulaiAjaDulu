# %%
import numpy as np
import scipy.stats as st
import seaborn as sns

sns.get_dataset_names ()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
penguins = sns.load_dataset('penguins').dropna()
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            344 non-null    object
#  1   island             344 non-null    object
#  2   bill_length_mm     342 non-null    float64
#  3   bill_depth_mm      342 non-null    float64
#  4   flipper_length_mm  342 non-null    float64
#  5   body_mass_g        342 non-null    float64
#  6   sex                333 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 18.9+ KB

# %% [markdown]
# # CENTRALL TENDENCIES
# - Mean
# - Median

# %%
penguins.mean()
# Out:
# <ipython-input-9-76b91d4faeb0>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguins.mean()
# bill_length_mm         43.921930
# bill_depth_mm          17.151170
# flipper_length_mm     200.915205
# body_mass_g          4201.754386
# dtype: float64

# %%
penguins.median()
# Out:
# <ipython-input-11-d1593eff4f8c>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   penguins.median()
# bill_length_mm         44.45
# bill_depth_mm          17.30
# flipper_length_mm     197.00
# body_mass_g          4050.00
# dtype: float64

# %% [markdown]
# # HISTOGRAM DAN SCATTER PLOT

# %%
import matplotlib.pyplot as plt

# %%
sns.histplot(penguins['bill_length_mm'], kde=True)
plt.title('Histogram Tinggi Tubuh Penguins')
plt.show()

# %%
sns.scatterplot(x='bill_length_mm', y='body_mass_g', data=penguins)
plt.title('Scatter Plot Tinggi Tubuh vs. Berat Badan Penguins')
plt.show()

# %%
sns.scatterplot(x='bill_length_mm', y='flipper_length_mm', data=penguins)
plt.title('Scatter Plot Tinggi Tubuh vs. Panjang Sayap Penguins')
plt.show()

# %%
_ = sns.boxplot(data=penguins)

# %% [markdown]
# Pairplot antar variable:
#
# - bill_length_mm: Panjang paruh penguin dalam milimeter.
# - bill_depth_mm: Kedalaman paruh penguin dalam milimeter.
# - flipper_length_mm: Panjang sayap penguin dalam milimeter.

# %%
sns.pairplot(penguins)

# %% [markdown]
# Definisi Species Penguins dan Jumlahnya dalam Vektor Array

# %%
np.unique(penguins.species, return_counts=True)
# Out:
# (array(['Adelie', 'Chinstrap', 'Gentoo'], dtype=object),
#  array([152,  68, 124]))

# %% [markdown]
# Definisi Species Penguins Adelie

# %%
adelie = penguins[penguins.species == 'Adelie']
adelie
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 147  Adelie      Dream            36.6           18.4              184.0
# 148  Adelie      Dream            36.0           17.8              195.0
# 149  Adelie      Dream            37.8           18.1              193.0
# 150  Adelie      Dream            36.0           17.1              187.0
# 151  Adelie      Dream            41.5           18.5              201.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# Definisi tiap Pulau yang punya species Penguin Adelie dan Jumlahnya dalam vektor array

# %%
np.unique(adelie.island, return_counts=True)
# Out:
# (array(['Biscoe', 'Dream', 'Torgersen'], dtype=object), array([44, 56, 52]))

# %% [markdown]
# Definisi tiap jenis kelamin species Penguin Adelie dan Jumlahnya dalam vektor array

# %%
np.unique(adelie.sex, return_counts=True)
# Out:
# (array(['Female', 'Male'], dtype=object), array([73, 73]))

# %% [markdown]
# Visualisasi dengan Box and Whisker Plot

# %%
_ = sns.boxplot(x='island', y='body_mass_g', hue='sex', data=adelie)

# %% [markdown]
# Variasi berat badan penguin (weight), berdasarkan jenis kelamin penguin (sex), yang terbagi menjadi female dan male.

# %%
f = adelie[adelie.sex == 'Female']['body_mass_g'].to_numpy()/1000
f
# Out:
# array([3.8  , 3.25 , 3.45 , 3.625, 3.2  , 3.7  , 3.45 , 3.325, 3.4  ,
#        3.8  , 3.8  , 3.2  , 3.15 , 3.25 , 3.3  , 3.325, 3.55 , 3.3  ,
#        3.15 , 3.1  , 3.   , 3.45 , 3.5  , 3.45 , 2.9  , 3.55 , 2.85 ,
#        3.15 , 3.6  , 2.85 , 3.35 , 3.05 , 3.6  , 3.55 , 3.7  , 3.7  ,
#        3.55 , 3.2  , 3.8  , 3.35 , 3.5  , 3.6  , 3.55 , 3.4  , 3.3  ,
#        3.7  , 2.9  , 3.725, 3.075, 2.925, 3.75 , 3.175, 3.825, 3.2  ,
#        3.9  , 2.9  , 3.35 , 3.15 , 3.45 , 3.05 , 3.275, 3.05 , 3.325,
#        3.5  , 3.425, 3.175, 3.4  , 3.4  , 3.05 , 3.   , 3.475, 3.45 ,
#        3.7  ])

# %%
m = adelie[adelie.sex == 'Male']['body_mass_g'].to_numpy()/1000
m
# Out:
# array([3.75 , 3.65 , 4.675, 3.8  , 4.4  , 4.5  , 4.2  , 3.6  , 3.95 ,
#        3.8  , 3.55 , 3.95 , 3.9  , 3.9  , 4.15 , 3.95 , 4.65 , 3.9  ,
#        4.4  , 4.6  , 3.425, 4.15 , 4.3  , 4.05 , 3.7  , 3.8  , 3.75 ,
#        4.4  , 4.05 , 3.95 , 4.1  , 4.45 , 3.9  , 4.15 , 4.25 , 3.9  ,
#        4.   , 4.7  , 4.2  , 3.55 , 3.8  , 3.95 , 4.3  , 4.45 , 4.3  ,
#        4.35 , 4.1  , 4.725, 4.25 , 3.55 , 3.9  , 4.775, 4.6  , 4.275,
#        4.075, 3.775, 3.325, 3.5  , 3.875, 4.   , 4.3  , 4.   , 3.5  ,
#        4.475, 3.9  , 3.975, 4.25 , 3.475, 3.725, 3.65 , 4.25 , 3.75 ,
#        4.   ])

# %% [markdown]
# Mean dari data berat badan penguin berdasarkan jenis kelamin female dan male

# %%
fbar =f.mean()
fbar
# Out:
# 3.368835616438356

# %%
mbar =m.mean()
mbar
# Out:
# 4.043493150684932

# %% [markdown]
# Menghitung variasi berat badan penguin berdasarkan jenis kelamin.

# %%
sf = f.var(ddof=1)
sm = m.var(ddof=1)

nf = f.size
nm = m.size

t = (fbar-mbar)/(sf/nf+sm/nm)**(1/2)
t
# Out:
# -13.126285923485879

# %% [markdown]
# Hitung derajat kebebasan p-value pakai Welch-Satterthwaite

# %%
def ws_eqn(sx,sy,nx,ny):
  return (sx/nx + sy/ny)**2 / (sx**2/(nx-1)) +sy**2/(ny**2 * (ny-1))
